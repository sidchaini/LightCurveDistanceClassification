# %%
import numpy as np
import pandas as pd
from tqdm.auto import tqdm
import matplotlib.pyplot as plt
import seaborn as sns
from mlxtend.feature_selection import (
    SequentialFeatureSelector,
)
from mlxtend.evaluate import feature_importance_permutation
from mlxtend.plotting import plot_sequential_feature_selection as plot_sfs
from sklearn.utils.estimator_checks import check_estimator
from sklearn.model_selection import cross_val_predict, train_test_split
from sklearn.metrics import accuracy_score, f1_score, matthews_corrcoef
import matplotlib.ticker as ticker
import os
from pathlib import Path
import json

import sys

sys.path.append("scripts")

import utils
import distclassipy as dcpy

cd = dcpy.Distance()

# %%
with open("settings.txt") as f:
    settings_dict = json.load(f)
np.random.seed(settings_dict["seed_choice"])

classification_letter = "b"
classification_problem = settings_dict["classification_problem"][classification_letter]
classes_to_keep = settings_dict["classes_to_keep"][classification_letter]
results_subfolder = f"{classification_letter}. {classification_problem}"
sns_dict = settings_dict["sns_dict"]

sns.set_theme(**sns_dict)

# %%
check_estimator(dcpy.DistanceMetricClassifier())  # passes

# %%
# Load Data
X_df_FULL = pd.read_csv("data/X_df.csv", index_col=0)
y_df_FULL = pd.read_csv("data/y_df.csv", index_col=0)

# %%
# Remove manually selected 'bad' features
with open(os.path.join("results", results_subfolder, "drop_features.txt")) as f:
    bad_features = json.load(f)  # manually selected

X_df_FULL = X_df_FULL.drop(bad_features, axis=1)

print(X_df_FULL.shape[1])
# Out:
# 36

# %%
# Keep only current classes
cl_keep_str = "_".join(classes_to_keep)

y_df = y_df_FULL[y_df_FULL["class"].isin(classes_to_keep)]
X_df = X_df_FULL.loc[y_df.index]
X = X_df.to_numpy()
y = y_df.to_numpy().ravel()

# %%
all_metrics = [
    "euclidean",
    "braycurtis",
    "canberra",
    "cityblock",
    "chebyshev",
    cd.clark,
    "correlation",
    "cosine",
    cd.hellinger,
    cd.jaccard,
    cd.lorentzian,
    cd.marylandbridge,
    cd.meehl,
    cd.motyka,
    cd.soergel,
    cd.wave_hedges,
    cd.kulczynski,
    cd.add_chisq,
]

scoring = "f1_macro"

# %%
from IPython.display import IFrame

# %%
with open(os.path.join("results", results_subfolder, "best_common_features.txt")) as f:
    best_common_features = json.load(f)

# %%
# for metric in tqdm([cd.wave_hedges]): EXAMINE wave_hedges, clark, add_chisq, maryland bridge

bestfeat_robust = []
common_best_feat = best_common_features[0]

for metric in tqdm(all_metrics):
    # for metric in tqdm([cd.clark, 'canberra', cd.hellinger]):
    metric_str = utils.get_metric_name(metric)
    locpath = os.path.join("results", results_subfolder, "distclassipy", metric_str)
    print("*" * 20, metric_str, "*" * 20)
    lcdc = dcpy.DistanceMetricClassifier(
        metric=metric, scale=True, 
        central_stat=settings_dict["central_stat"], 
        dispersion_stat=settings_dict["dispersion_stat"],
        calculate_kde=False, calculate_1d_dist=False
    )

    # Load best min features within 1 std of best score.
    sfs_df = pd.read_csv(os.path.join(locpath, "sfs_allfeatures.csv"), index_col=0)
    feats_idx, feats = utils.load_best_features(sfs_df)

    all_feats = X_df.columns

    # show SFS plot from before for this metric
    filepath = os.path.join(locpath, "sfs_allfeatures_plot_marked.pdf")
    display(IFrame(filepath, width=700, height=500))

    # Calculate the score for each quantile
    newfeats = []
    feat_quantile_scores = []

    # print("Total test score of all quantiles together:")

    # pbar = tqdm(feats, leave=False) # Loop through "best feats"
    pbar = tqdm(best_common_features, leave=False)  # Loop through best_common_features
    for feat in pbar:
        pbar.set_description(f"Feature: {feat}")
        try:
            quantiles = pd.qcut(X_df.loc[:, feat], q=4)  # q is number of splits
        except ValueError as ve:
            print(f"{feat}: {ve}. Continuing.")
            continue

        X_df_subset = X_df.loc[
            :, feats
        ]  # X_df with just the features important for this metric
        # X_df_subset["quantile"] = quantiles

        X = X_df_subset.to_numpy()
        # X_train, X_test, y_train, y_test = train_test_split(X_df_subset,y, test_size=0.33, stratify=[feat])
        X_train, X_test, y_train, y_test = train_test_split(
            X_df_subset, y_df, test_size=0.33, stratify=quantiles, random_state=44
        )

        lcdc.fit(X_train, y_train.to_numpy().ravel())
        acc_tot = lcdc.score(X_test, y_test)
        # y_preds_tot = lcdc.predict(X_test)
        # f1_tot = f1_score(y_preds_tot, y_test, average="macro")
        print(f"\t{feat} feature: {acc_tot:.2f}")
        # print(f"\t{feat} feature: {f1_tot:.2f}")
        grouped = X_test.groupby(quantiles)

        quantile_scores = []
        for i, (lims, subdf) in enumerate(grouped):
            y_pred = lcdc.predict(subdf.to_numpy())
            y_true = y_test.loc[subdf.index]
            # print(y_true["class"].value_counts())
            # f1 = f1_score(y_true, y_pred, average='macro')
            acc = accuracy_score(y_true, y_pred)

            # quantile_scores.append(f1)
            quantile_scores.append(acc)
        feat_quantile_scores.append(quantile_scores)
        newfeats.append(feat)

    feat_quantile_scores = np.array(feat_quantile_scores) * 100  # Change to percentage

    feat_quantile_scores_df = pd.DataFrame(
        data=feat_quantile_scores,
        index=newfeats,
        columns=[f"Quantile {i+1}" for i in range(4)],
    )
    # sorted by best-wors feats by default

    # CHANGE AXES FIG RATIO

    fig, ax = plt.subplots()
    sns.heatmap(
        feat_quantile_scores_df,
        ax=ax,
        annot=True,
        fmt=".0f",
        vmin=75,
        vmax=100,
        cmap="Blues",
        cbar_kws={"label": "Accuracy (%)"},
    )

    ax.set_title(f"{metric_str.title()} metric")
    ax.set_ylabel("Feature Name")

    # Embolden (or color red) the selected labels on the y axis
    ytick_labels = ax.get_yticklabels()
    # label_colors = [sns.color_palette()[3] if f in feats else 'black' for f in pbar]
    label_fontweights = ["bold" if f in feats else None for f in pbar]

    # for tick_label, color in zip(ytick_labels, label_colors):
    #     tick_label.set_color(color)
    for tick_label, fw in zip(ytick_labels, label_fontweights):
        tick_label.set_fontweight(fw)

    plt.savefig(os.path.join(locpath, "robustness_plot.pdf"), bbox_inches="tight")
    plt.show()

    sr = feat_quantile_scores_df.loc[common_best_feat]
    sr.name = metric_str
    bestfeat_robust.append(sr)
# Out:
#   0%|          | 0/18 [00:00<?, ?it/s]
# ******************** Euclidean ********************
#         <iframe
#             width="700"
#             height="500"
#             src="results/b. binary/distclassipy/Euclidean/sfs_allfeatures_plot_marked.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
#   0%|          | 0/8 [00:00<?, ?it/s]
# 	Psi_eta_r feature: 0.67
# 	Rcs_r feature: 0.69
# 	Psi_CS_r feature: 0.68
# 	MHPS_ratio_r feature: 0.64
# 	Harmonics_mag_6_r feature: 0.68
# 	SF_ML_gamma_r feature: 0.66
# 	Harmonics_phase_3_r feature: 0.68
# 	LinearTrend_r feature: 0.67
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# ******************** Braycurtis ********************
#         <iframe
#             width="700"
#             height="500"
#             src="results/b. binary/distclassipy/Braycurtis/sfs_allfeatures_plot_marked.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
#   0%|          | 0/8 [00:00<?, ?it/s]
# 	Psi_eta_r feature: 0.64
# 	Rcs_r feature: 0.67
# 	Psi_CS_r feature: 0.66
# 	MHPS_ratio_r feature: 0.66
# 	Harmonics_mag_6_r feature: 0.65
# 	SF_ML_gamma_r feature: 0.65
# 	Harmonics_phase_3_r feature: 0.65
# 	LinearTrend_r feature: 0.65
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# ******************** Canberra ********************
#         <iframe
#             width="700"
#             height="500"
#             src="results/b. binary/distclassipy/Canberra/sfs_allfeatures_plot_marked.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
#   0%|          | 0/8 [00:00<?, ?it/s]
# 	Psi_eta_r feature: 0.62
# 	Rcs_r feature: 0.63
# 	Psi_CS_r feature: 0.61
# 	MHPS_ratio_r feature: 0.62
# 	Harmonics_mag_6_r feature: 0.62
# 	SF_ML_gamma_r feature: 0.62
# 	Harmonics_phase_3_r feature: 0.62
# 	LinearTrend_r feature: 0.64
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# ******************** Cityblock ********************
#         <iframe
#             width="700"
#             height="500"
#             src="results/b. binary/distclassipy/Cityblock/sfs_allfeatures_plot_marked.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
#   0%|          | 0/8 [00:00<?, ?it/s]
# 	Psi_eta_r feature: 0.68
# 	Rcs_r feature: 0.65
# 	Psi_CS_r feature: 0.65
# 	MHPS_ratio_r feature: 0.64
# 	Harmonics_mag_6_r feature: 0.66
# 	SF_ML_gamma_r feature: 0.64
# 	Harmonics_phase_3_r feature: 0.66
# 	LinearTrend_r feature: 0.60
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# ******************** Chebyshev ********************
#         <iframe
#             width="700"
#             height="500"
#             src="results/b. binary/distclassipy/Chebyshev/sfs_allfeatures_plot_marked.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
#   0%|          | 0/8 [00:00<?, ?it/s]
# 	Psi_eta_r feature: 0.68
# 	Rcs_r feature: 0.65
# 	Psi_CS_r feature: 0.66
# 	MHPS_ratio_r feature: 0.68
# 	Harmonics_mag_6_r feature: 0.66
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# 	SF_ML_gamma_r feature: 0.67
# 	Harmonics_phase_3_r feature: 0.69
# 	LinearTrend_r feature: 0.72
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# ******************** Clark ********************
#         <iframe
#             width="700"
#             height="500"
#             src="results/b. binary/distclassipy/Clark/sfs_allfeatures_plot_marked.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
#   0%|          | 0/8 [00:00<?, ?it/s]
# 	Psi_eta_r feature: 0.66
# 	Rcs_r feature: 0.63
# 	Psi_CS_r feature: 0.64
# 	MHPS_ratio_r feature: 0.66
# 	Harmonics_mag_6_r feature: 0.66
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# 	SF_ML_gamma_r feature: 0.65
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# 	Harmonics_phase_3_r feature: 0.66
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# 	LinearTrend_r feature: 0.70
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# ******************** Correlation ********************
#         <iframe
#             width="700"
#             height="500"
#             src="results/b. binary/distclassipy/Correlation/sfs_allfeatures_plot_marked.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
#   0%|          | 0/8 [00:00<?, ?it/s]
# 	Psi_eta_r feature: 0.66
# 	Rcs_r feature: 0.67
# 	Psi_CS_r feature: 0.62
# 	MHPS_ratio_r feature: 0.64
# 	Harmonics_mag_6_r feature: 0.67
# 	SF_ML_gamma_r feature: 0.64
# 	Harmonics_phase_3_r feature: 0.63
# 	LinearTrend_r feature: 0.67
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# ******************** Cosine ********************
#         <iframe
#             width="700"
#             height="500"
#             src="results/b. binary/distclassipy/Cosine/sfs_allfeatures_plot_marked.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
#   0%|          | 0/8 [00:00<?, ?it/s]
# 	Psi_eta_r feature: 0.70
# 	Rcs_r feature: 0.66
# 	Psi_CS_r feature: 0.65
# 	MHPS_ratio_r feature: 0.69
# 	Harmonics_mag_6_r feature: 0.67
# 	SF_ML_gamma_r feature: 0.69
# 	Harmonics_phase_3_r feature: 0.67
# 	LinearTrend_r feature: 0.67
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# ******************** Hellinger ********************
#         <iframe
#             width="700"
#             height="500"
#             src="results/b. binary/distclassipy/Hellinger/sfs_allfeatures_plot_marked.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
#   0%|          | 0/8 [00:00<?, ?it/s]
# 	Psi_eta_r feature: 0.66
# 	Rcs_r feature: 0.66
# 	Psi_CS_r feature: 0.65
# 	MHPS_ratio_r feature: 0.67
# 	Harmonics_mag_6_r feature: 0.67
# 	SF_ML_gamma_r feature: 0.66
# 	Harmonics_phase_3_r feature: 0.66
# 	LinearTrend_r feature: 0.69
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# ******************** Jaccard ********************
#         <iframe
#             width="700"
#             height="500"
#             src="results/b. binary/distclassipy/Jaccard/sfs_allfeatures_plot_marked.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
#   0%|          | 0/8 [00:00<?, ?it/s]
# 	Psi_eta_r feature: 0.68
# 	Rcs_r feature: 0.70
# 	Psi_CS_r feature: 0.67
# 	MHPS_ratio_r feature: 0.69
# 	Harmonics_mag_6_r feature: 0.69
# 	SF_ML_gamma_r feature: 0.70
# 	Harmonics_phase_3_r feature: 0.68
# 	LinearTrend_r feature: 0.67
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# ******************** Lorentzian ********************
#         <iframe
#             width="700"
#             height="500"
#             src="results/b. binary/distclassipy/Lorentzian/sfs_allfeatures_plot_marked.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
#   0%|          | 0/8 [00:00<?, ?it/s]
# 	Psi_eta_r feature: 0.64
# 	Rcs_r feature: 0.66
# 	Psi_CS_r feature: 0.63
# 	MHPS_ratio_r feature: 0.63
# 	Harmonics_mag_6_r feature: 0.63
# 	SF_ML_gamma_r feature: 0.63
# 	Harmonics_phase_3_r feature: 0.61
# 	LinearTrend_r feature: 0.63
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# ******************** Marylandbridge ********************
#         <iframe
#             width="700"
#             height="500"
#             src="results/b. binary/distclassipy/Marylandbridge/sfs_allfeatures_plot_marked.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
#   0%|          | 0/8 [00:00<?, ?it/s]
# 	Psi_eta_r feature: 0.67
# 	Rcs_r feature: 0.64
# 	Psi_CS_r feature: 0.62
# 	MHPS_ratio_r feature: 0.62
# 	Harmonics_mag_6_r feature: 0.66
# 	SF_ML_gamma_r feature: 0.66
# 	Harmonics_phase_3_r feature: 0.64
# 	LinearTrend_r feature: 0.65
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# ******************** Meehl ********************
#         <iframe
#             width="700"
#             height="500"
#             src="results/b. binary/distclassipy/Meehl/sfs_allfeatures_plot_marked.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
#   0%|          | 0/8 [00:00<?, ?it/s]
# 	Psi_eta_r feature: 0.67
# 	Rcs_r feature: 0.66
# 	Psi_CS_r feature: 0.65
# 	MHPS_ratio_r feature: 0.67
# 	Harmonics_mag_6_r feature: 0.69
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# 	SF_ML_gamma_r feature: 0.67
# 	Harmonics_phase_3_r feature: 0.67
# 	LinearTrend_r feature: 0.67
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# ******************** Motyka ********************
#         <iframe
#             width="700"
#             height="500"
#             src="results/b. binary/distclassipy/Motyka/sfs_allfeatures_plot_marked.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
#   0%|          | 0/8 [00:00<?, ?it/s]
# 	Psi_eta_r feature: 0.63
# 	Rcs_r feature: 0.65
# 	Psi_CS_r feature: 0.64
# 	MHPS_ratio_r feature: 0.66
# 	Harmonics_mag_6_r feature: 0.64
# 	SF_ML_gamma_r feature: 0.65
# 	Harmonics_phase_3_r feature: 0.63
# 	LinearTrend_r feature: 0.64
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# ******************** Soergel ********************
#         <iframe
#             width="700"
#             height="500"
#             src="results/b. binary/distclassipy/Soergel/sfs_allfeatures_plot_marked.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
#   0%|          | 0/8 [00:00<?, ?it/s]
# 	Psi_eta_r feature: 0.63
# 	Rcs_r feature: 0.65
# 	Psi_CS_r feature: 0.64
# 	MHPS_ratio_r feature: 0.66
# 	Harmonics_mag_6_r feature: 0.64
# 	SF_ML_gamma_r feature: 0.65
# 	Harmonics_phase_3_r feature: 0.63
# 	LinearTrend_r feature: 0.64
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# ******************** Wave_Hedges ********************
#         <iframe
#             width="700"
#             height="500"
#             src="results/b. binary/distclassipy/Wave_Hedges/sfs_allfeatures_plot_marked.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
#   0%|          | 0/8 [00:00<?, ?it/s]
# 	Psi_eta_r feature: 0.62
# 	Rcs_r feature: 0.63
# 	Psi_CS_r feature: 0.61
# 	MHPS_ratio_r feature: 0.62
# 	Harmonics_mag_6_r feature: 0.62
# 	SF_ML_gamma_r feature: 0.62
# 	Harmonics_phase_3_r feature: 0.62
# 	LinearTrend_r feature: 0.64
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# ******************** Kulczynski ********************
#         <iframe
#             width="700"
#             height="500"
#             src="results/b. binary/distclassipy/Kulczynski/sfs_allfeatures_plot_marked.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
#   0%|          | 0/8 [00:00<?, ?it/s]
# 	Psi_eta_r feature: 0.63
# 	Rcs_r feature: 0.65
# 	Psi_CS_r feature: 0.64
# 	MHPS_ratio_r feature: 0.66
# 	Harmonics_mag_6_r feature: 0.64
# 	SF_ML_gamma_r feature: 0.65
# 	Harmonics_phase_3_r feature: 0.63
# 	LinearTrend_r feature: 0.64
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# ******************** Add_Chisq ********************
#         <iframe
#             width="700"
#             height="500"
#             src="results/b. binary/distclassipy/Add_Chisq/sfs_allfeatures_plot_marked.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
#   0%|          | 0/8 [00:00<?, ?it/s]
# 	Psi_eta_r feature: 0.66
# 	Rcs_r feature: 0.64
# 	Psi_CS_r feature: 0.65
# 	MHPS_ratio_r feature: 0.67
# 	Harmonics_mag_6_r feature: 0.66
# 	SF_ML_gamma_r feature: 0.66
# 	Harmonics_phase_3_r feature: 0.67
# 	LinearTrend_r feature: 0.70
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# /var/folders/2d/ht34x6mn7hx9d1sv4g_j8nfr0000gn/T/ipykernel_69110/139227569.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = X_test.groupby(quantiles)
# 	MHPS_low_r feature: 0.91
# 	Rcs_r feature: 0.92
# 	MHPS_ratio_r feature: 0.91
# 	Harmonics_mag_1_r feature: 0.92
# 	Psi_eta_r feature: 0.92
# 	Harmonics_phase_5_r feature: 0.92
# 	Amplitude_r feature: 0.92
# 	Harmonics_mag_7_r feature: 0.91
# 	Beyond1Std_r feature: 0.91
# 	Eta_e_r feature: 0.92
# 	Gskew_r feature: 0.92

# %%
bestfeat_robust = pd.DataFrame(bestfeat_robust)
bestfeat_robust.index.name = common_best_feat
bestfeat_robust.index = bestfeat_robust.index.str.title()

# %%
columns = [f"Quantile {i+1}" for i in range(4)]

# %%
locpath
# Out:
# 'results/b. binary/distclassipy/Add_Chisq'

# %%
fig, ax = plt.subplots()
sns.heatmap(
    bestfeat_robust,
    ax=ax,
    annot=True,
    fmt=".0f",
    # vmin=80,
    vmax=100,
    cmap="Blues",
    cbar_kws={"label": "Accuracy (%)"},
)

ax.set_title(f"Quantiles for {common_best_feat}")
ax.set_ylabel("Metric")

plt.savefig(
    os.path.join(
        "results", results_subfolder, "distclassipy", "robustness_bestfeat.pdf"
    ),
    bbox_inches="tight",
)
plt.show()

# %%
# fig, ax = plt.subplots()
# sns.heatmap(bestfeat_robust, ax=ax,
#             annot=True, fmt='.0f',
#             # vmin=80,
#             vmax=100,
#             cmap="Blues",
#             cbar_kws={'label': 'Accuracy (%)'})

# ax.set_title(f"Quantiles for {common_best_feat}")
# ax.set_ylabel("Metric")

# plt.savefig(f"results/robustness_bestfeat.svg", bbox_inches = 'tight')
# plt.show()

# %% [markdown]
# In the robustness plot, I added all features on y axis, with the relevant ones for each metric coloured red. I also created a robustness plot for different features
