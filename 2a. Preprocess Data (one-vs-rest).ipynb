# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import json
import os
from pathlib import Path
import matplotlib.gridspec as gridspec

# %%
with open("settings.txt") as f:
    settings_dict = json.load(f)
np.random.seed(settings_dict["seed_choice"])

classification_letter = "a"
classification_problem = settings_dict["classification_problem"][classification_letter]
classes_to_keep = settings_dict["classes_to_keep"][classification_letter]
results_subfolder = f"{classification_letter}. {classification_problem}"
sns_dict = settings_dict["sns_dict"]

sns.set_theme(**sns_dict)

# %%
# Load Data
X_df_FULL = pd.read_csv("data/X_df.csv", index_col=0)
y_df_FULL = pd.read_csv("data/y_df.csv", index_col=0)

# %%
print(len(X_df_FULL.columns))
# Out:
# 112

# %%
# Only for one-vs-rest
cl_keep_str = "_".join(classes_to_keep)


posclass_df = y_df_FULL[y_df_FULL["class"].isin(classes_to_keep)]
negclass_df = y_df_FULL[~y_df_FULL["class"].isin(classes_to_keep)].sample(
    n=len(posclass_df)
)

negclass_df["class"] = f"Not{classes_to_keep[0]}"

# Remove feats from (1) and (2) and keep only 4 classes
y_df = pd.concat([posclass_df, negclass_df]).sample(frac=1)  # Shuffle
X_df = X_df_FULL.loc[y_df.index]

bigdf = X_df.join(y_df)

# %% [markdown]
# ## 0. Scatter/histogram b/w individual features

# %%
corr_matrix = X_df.corr()
vars_interest = ["Harmonics_mag_1_r", "Harmonics_mag_2_r"]
corr_val = corr_matrix.loc[vars_interest[0], vars_interest[1]]
ax = sns.pairplot(
    bigdf,
    vars=vars_interest,
    hue="class",
    corner=True,
    markers=["o", "^", "s", "*"],
)
plt.suptitle(f"Correlation = {corr_val:.2f}")
plt.tight_layout()
sns.move_legend(ax, "upper left", bbox_to_anchor=(0.675, 0.9))
# https://stackoverflow.com/a/34579525/10743245

var1_lims = (0, 0.45)
var2_lims = (0, 0.25)

ax.axes.ravel()[0].set_xlim(*var1_lims)
ax.axes.ravel()[2].set_xlim(*var1_lims)
ax.axes.ravel()[2].set_ylim(*var2_lims)
ax.axes.ravel()[3].set_xlim(*var2_lims)

Path("results", results_subfolder).mkdir(parents=True, exist_ok=True)
plt.savefig(
    os.path.join("results", results_subfolder, "harmonics_corr.pdf"),
    bbox_inches="tight",
)
plt.show()

# %% [markdown]
# ## 1. Remove all g features. Keep r and multiband only

# %%
## REMOVE g-band features. Keep r-band and multiband features only

gband_features = []
for c in X_df_FULL.columns:
    if c.endswith("_g"):
        gband_features.append(c)
    else:
        continue

# %%
len(gband_features)
# Out:
# 52

# %% [markdown]
# ## 2. Manually inspect feature descriptions and remove

# %%
newdf = pd.read_csv("data/.temp_feature_description", index_col=0)

# Go to the following link for interactive spreadsheet
# https://docs.google.com/spreadsheets/d/1EDzk51Nzk6jhGbZhimN3iQiRkba_NCRN6Uoxi6eTzoU/

newdf
# Out:
#                   KEEP?                                             Reason  \
# Feature name
# Amplitude           YES  Because different classes have different ampli...
# AndersonDarling     YES  Different classes may have light curves that c...
# Autocor_length      YES  Because the autocorrelation can be different f...
# Beyond1Std          YES  Because this tells us how many points suddenly...
# Con                  NO  Irregular time series, so number of points bad...
# delta_period         NO  Just tells us about different fits, nothing ab...
# Eta_e               YES  Measures trend of lightcurve degree of variaba...
# ExcessVar           YES                     Measures intrinsic variability
# GP_DRW_sigma        YES           Measures variability at short timescales
# GP_DRW_tau          YES                  Measures timescale of variability
#   tc                YES                           Tells about skew (shape)
# Harmonics_mag_1     YES  Harmonic series tells us if it has a single/mu...
# Harmonics_mag_2     YES  Higher harmonic components may represent short...
# Harmonics_mag_3     YES                                                NaN
# Harmonics_mag_4     YES                                                NaN
# Harmonics_mag_5     YES                                                NaN
# Harmonics_mag_6     YES                                                NaN
# Harmonics_mag_7     YES                                                NaN
# Harmonics_mse        NO                         Error of fit not important
# Harmonics_phase_2   YES     Serves as a timescale for highest harmonic fit
# Harmonics_phase_3   YES                                                NaN
# Harmonics_phase_4   YES                                                NaN
# Harmonics_phase_5   YES                                                NaN
# Harmonics_phase_6   YES                                                NaN
# Harmonics_phase_7   YES                                                NaN
# IAR_phi             YES  Because the autocorrelation can be different f...
# LinearTrend         YES    Tells us about shape (linearity) of light curve
# MaxSlope             NO                       Depends on number of points.
# Mean                YES    Brightness for different stars can be different
# Meanvariance        YES     Tells us about how much the light curve varies
# MedianAbsDev        YES     Tells us about how much the light curve varies
# MedianBRP           YES               Tells us about degree of variability
# MHPS_high           YES         Looks at structures of timescales ~10 days
# MHPS_low            YES        Looks at structures of timescales ~100 days
# MHPS_PN_flag         NO                 A flag shouldn't matter physically
# MHPS_ratio          YES  The logarithm of MHPS_ratio is therefore an es...
# PairSlopeTrend       NO       Not a good measure for irregular time series
# PercentAmplitude    YES                       Gives a range of variability
# Period_band         YES                         Characteristic of variable
# Psi_CS              YES      Time-folding gives better values for periodic
# Psi_eta             YES      Time-folding gives better values for periodic
# Pvar                YES                            Tells about variability
# Q31                 YES                                  Tells about shape
# Rcs                 YES                            Tells about periodicity
# SF_ML_amplitude     YES     Structure function is a measure of variability
# SF_ML_gamma         YES     Structure function is a measure of variability
# Skew                YES                Tells us about shape of light curve
# SmallKurtosis       YES  variability index derived based on the autocor...
# Std                 YES                            Tells about variability
# StetsonK            YES  variability index derived based on the autocor...
# MHPS_non_zero        NO                                of each light curve
# iqr                  NO                                          REDUNDANT
# Multiband_period     NO                             Already using period_r
# Power_rate_1/2       NO                     A measure of periodogram value
# Power_rate_1/3       NO                     A measure of periodogram value
# Power_rate_1/4       NO                     A measure of periodogram value
# Power_rate_2         NO                     A measure of periodogram value
# Power_rate_3         NO                     A measure of periodogram value
# Power_rate_4         NO                     A measure of periodogram value
# PPE                  NO                    A confidence measure for period
#
#                                                          Description  Source  \
# Feature name
# Amplitude          Half of the difference between the median of t...  ALeRCE
# AndersonDarling    Test of whether a sample of data comes from a ...  ALeRCE
# Autocor_length     Lag value where the auto-correlation function ...  ALeRCE
# Beyond1Std         Percentage of points with photometric mag that...  ALeRCE
# Con                Number of three consecutive data points bright...  ALeRCE
# delta_period       Absolute value of the difference between the M...  ALeRCE
# Eta_e              Ratio of the mean of the squares of successive...  ALeRCE
# ExcessVar          Measure of the intrinsic variability amplitude...  ALeRCE
# GP_DRW_sigma       Amplitude of the variability at short timescal...  ALeRCE
# GP_DRW_tau                   Relaxation time (tau) from DRW modeling  ALeRCE
#   tc                                Median-based measure of the skew  ALeRCE
# Harmonics_mag_1    Amplitude of the 1st component of the harmonic...  ALeRCE
# Harmonics_mag_2    Amplitude of the 2nd component of the harmonic...  ALeRCE
# Harmonics_mag_3    Amplitude of the 3rd component of the harmonic...  ALeRCE
# Harmonics_mag_4    Amplitude of the 4th component of the harmonic...  ALeRCE
# Harmonics_mag_5    Amplitude of the 5th component of the harmonic...  ALeRCE
# Harmonics_mag_6    Amplitude of the 6th component of the harmonic...  ALeRCE
# Harmonics_mag_7    Amplitude of the 7th component of the harmonic...  ALeRCE
# Harmonics_mse      Mean squarre error of the harmonics series (ob...  ALeRCE
# Harmonics_phase_2  Phase of the 2nd component of the harmonics se...  ALeRCE
# Harmonics_phase_3  Phase of the 3rd component of the harmonics se...  ALeRCE
# Harmonics_phase_4  Phase of the 4th component of the harmonics se...  ALeRCE
# Harmonics_phase_5  Phase of the 5th component of the harmonics se...  ALeRCE
# Harmonics_phase_6  Phase of the 6th component of the harmonics se...  ALeRCE
# Harmonics_phase_7  Phase of the 7th component of the harmonics se...  ALeRCE
# IAR_phi            Level of autocorrelation using a discrete-time...  ALeRCE
# LinearTrend                 Slope of a linear fit to the light curve  ALeRCE
# MaxSlope           Maximum absolute magnitude slope between two c...  ALeRCE
# Mean               Mean lc_corr magnitude (or mean lc_diff if the...  ALeRCE
# Meanvariance       Ratio of the standard deviation to the mean ma...  ALeRCE
# MedianAbsDev       Median discrepancy of the data from the median...  ALeRCE
# MedianBRP          Percentage of fluxes within 20% of the amplitu...  ALeRCE
# MHPS_high          Variance associated with a 10 day timescale ob...  ALeRCE
# MHPS_low           Variance associated with a 100 day timescale o...  ALeRCE
# MHPS_PN_flag       Flag that reports whether the Poisson Noise is...  ALeRCE
# MHPS_ratio         Ratio between the MHPS_low and MHPS_high varia...  ALeRCE
# PairSlopeTrend     Fraction of increasing first differences minus...  ALeRCE
# PercentAmplitude   Largest percentage difference between either m...  ALeRCE
# Period_band        Single band period computed using a Multi Harm...  ALeRCE
# Psi_CS             Range of a cumulative sum applied to the phase...  ALeRCE
# Psi_eta            Eta_e index calculated from the folded light c...  ALeRCE
# Pvar               Probability that the source is intrinsically v...  ALeRCE
# Q31                Difference between the 3rd and the 1st quartil...  ALeRCE
# Rcs                                        Range of a cumulative sum  ALeRCE
# SF_ML_amplitude    Rms magnitude difference of the structure func...  ALeRCE
# SF_ML_gamma        Logarithmic gradient of the mean change in mag...  ALeRCE
# Skew                                                Skewness measure  ALeRCE
# SmallKurtosis                Small sample kurtosis of the magnitudes  ALeRCE
# Std                            Standard deviation of the light curve  ALeRCE
# StetsonK                                     Robust kurtosis measure  ALeRCE
# MHPS_non_zero                                                    ???  EXTRA?
# iqr                                  Interquartile-range - REDUNDANT  EXTRA?
# Multiband_period   Period obtained using the multiband MHAOV peri...  ALeRCE
# Power_rate_1/2     Ratio between the power of the multiband perio...  ALeRCE
# Power_rate_1/3     Ratio between the power of the multiband perio...  ALeRCE
# Power_rate_1/4     Ratio between the power of the multiband perio...  ALeRCE
# Power_rate_2       Ratio between the power of the multiband perio...  ALeRCE
# Power_rate_3       Ratio between the power of the multiband perio...  ALeRCE
# Power_rate_4       Ratio between the power of the multiband perio...  ALeRCE
# PPE                             Multiband Periodogram Pseudo Entropy  ALeRCE
#
#                   bands (g, r, or multiband)
# Feature name
# Amplitude                            g and r
# AndersonDarling                      g and r
# Autocor_length                       g and r
# Beyond1Std                           g and r
# Con                                  g and r
# delta_period                         g and r
# Eta_e                                g and r
# ExcessVar                            g and r
# GP_DRW_sigma                         g and r
# GP_DRW_tau                           g and r
#   tc                                 g and r
# Harmonics_mag_1                      g and r
# Harmonics_mag_2                      g and r
# Harmonics_mag_3                      g and r
# Harmonics_mag_4                      g and r
# Harmonics_mag_5                      g and r
# Harmonics_mag_6                      g and r
# Harmonics_mag_7                      g and r
# Harmonics_mse                        g and r
# Harmonics_phase_2                    g and r
# Harmonics_phase_3                    g and r
# Harmonics_phase_4                    g and r
# Harmonics_phase_5                    g and r
# Harmonics_phase_6                    g and r
# Harmonics_phase_7                    g and r
# IAR_phi                              g and r
# LinearTrend                          g and r
# MaxSlope                             g and r
# Mean                                 g and r
# Meanvariance                         g and r
# MedianAbsDev                         g and r
# MedianBRP                            g and r
# MHPS_high                            g and r
# MHPS_low                             g and r
# MHPS_PN_flag                         g and r
# MHPS_ratio                           g and r
# PairSlopeTrend                       g and r
# PercentAmplitude                     g and r
# Period_band                          g and r
# Psi_CS                               g and r
# Psi_eta                              g and r
# Pvar                                 g and r
# Q31                                  g and r
# Rcs                                  g and r
# SF_ML_amplitude                      g and r
# SF_ML_gamma                          g and r
# Skew                                 g and r
# SmallKurtosis                        g and r
# Std                                  g and r
# StetsonK                             g and r
# MHPS_non_zero                        g and r
# iqr                                  g and r
# Multiband_period                   multiband
# Power_rate_1/2                     multiband
# Power_rate_1/3                     multiband
# Power_rate_1/4                     multiband
# Power_rate_2                       multiband
# Power_rate_3                       multiband
# Power_rate_4                       multiband
# PPE                                multiband

# %%
# Remove manually selected 'bad' features
bad_features = [
    "Con_r",
    "delta_period_r",
    "Harmonics_mse_r",
    "MaxSlope_r",
    "MHPS_PN_flag_r",
    "PairSlopeTrend_r",
    "MHPS_non_zero_r",
    "iqr_r",
    "Multiband_period",
    "Power_rate_1/2",
    "Power_rate_1/3",
    "Power_rate_1/4",
    "Power_rate_2",
    "Power_rate_3",
    "Power_rate_4",
    "PPE",
]  # manually selected

# %%
len(bad_features)
# Out:
# 16

# %% [markdown]
# ## 3. Drop features having a high correlation in the full dataset for this quaternary classification problem

# %%
corr_thresh = 0.9

# %%
X_df_FULL = X_df_FULL.drop(bad_features, axis=1).drop(gband_features, axis=1)

X_df = X_df_FULL.loc[y_df.index]
bigdf = X_df.join(y_df)

# %%
# Compute the correlation matrix
corr_matrix = X_df.loc[:, sorted(X_df.columns)].corr().abs()

# %%
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype("bool"))

# %%
upper = upper[upper >= corr_thresh].dropna(axis=1, how="all")
upper = upper.sort_values(by=list(upper.columns), ascending=False)

# %%
lists = []

for idx in upper.index:
    row = upper.loc[idx].dropna()
    ls = sorted(list(row.index) + [row.name])
    lists.append(ls)

# %% [markdown]
# We only want to keep one feature for each subset of features that are highly correlated.

# %%
# lists = [[1, 3], [3, 5], [5, 6], [7, 8]]
merged = []
for lst in lists:
    for m in merged:
        if any(item in m for item in lst):
            m.extend(lst)
            break
    else:
        merged.append(lst)

merged_alt = []
for m in merged:
    merged_alt.append(list(set(m)))
merged = merged_alt
# print(merged)

# %%
for m in merged:
    if len(m) > 1:
        print("\n\t".join(m))
        print("*" * 10)
# Out:
# ExcessVar_r
# 	Std_r
# 	MedianAbsDev_r
# 	Meanvariance_r
# 	SF_ML_amplitude_r
# 	Amplitude_r
# 	Q31_r
# 	GP_DRW_sigma_r
# **********
# Harmonics_mag_4_r
# 	Harmonics_mag_1_r
# 	Harmonics_mag_6_r
# 	Harmonics_mag_3_r
# 	Harmonics_mag_2_r
# 	Harmonics_mag_7_r
# 	Harmonics_mag_5_r
# **********
# Beyond1Std_r
# 	MedianBRP_r
# **********

# %%
# manually choose one from each subset
# edit - choose the one with the highest SNR or the one with the STD
# alternate programmatic approach - look at diff clusters
choose_corrfeats = ["Amplitude_r", "Harmonics_mag_1_r", "Beyond1Std_r"]

# %%
bigset = []
for m in merged:
    if len(m) > 1:
        bigset.append(m)
bigset = [item for subset in bigset for item in subset]

drop_corrfeats = list(set(bigset) - set(choose_corrfeats))

# %%
len(drop_corrfeats)
# Out:
# 14

# %% [markdown]
# ## 4. Combine and drop all features

# %%
drop_features = (
    list(sorted(gband_features))
    + list(sorted(bad_features))
    + list(sorted(drop_corrfeats))
)

# %%
# Drop duplicates while preserving order
drop_features = list(dict.fromkeys(drop_features))

# %%
# Load Data
X_df_FULL = pd.read_csv("data/X_df.csv", index_col=0)
y_df_FULL = pd.read_csv("data/y_df.csv", index_col=0)

# %%
fig = plt.figure(figsize=(5.5, 5.5))
gs = gridspec.GridSpec(3, 2, height_ratios=[1, 1, 0.1], hspace=0.25, wspace=0)

axs = [plt.subplot(gs[0, 0]), plt.subplot(gs[0, 1]), plt.subplot(gs[2, :])]

for (cl, subdf), ax in zip(bigdf.groupby("class"), axs[:2]):
    corr_matrix = subdf.drop(["class"], axis=1).corr(method="pearson")

    im = ax.imshow(corr_matrix, cmap="RdBu", clim=(-1, 1))
    ax.set_title(f"{cl} class")
    ax.grid()
    ax.set_xticks([])
    ax.set_yticks([])

# Create a colorbar
cbar = plt.colorbar(im, cax=axs[2], orientation="horizontal")
cbar.set_label("Correlation")

# axs[4].axis('off')  # Turn off the axis for the colorbar subplot

# plt.tight_layout()
plt.savefig(
    os.path.join("results", results_subfolder, "corr_matrix_before.pdf"),
    bbox_inches="tight",
)
plt.show()

# %%
print(f"Original no. of features: {X_df_FULL.shape[1]}")
X_df_FULL = X_df_FULL.drop(drop_features, axis=1)
print(f"Reduced no. of features: {X_df_FULL.shape[1]}")
# Out:
# Original no. of features: 112
# Reduced no. of features: 30

# %%
X_df = X_df_FULL.loc[y_df.index]
bigdf = X_df.join(y_df)

# %%
import matplotlib.gridspec as gridspec


fig = plt.figure(figsize=(5.5, 5.5))
gs = gridspec.GridSpec(3, 2, height_ratios=[1, 1, 0.1], hspace=0.25, wspace=0)

axs = [plt.subplot(gs[0, 0]), plt.subplot(gs[0, 1]), plt.subplot(gs[2, :])]

for (cl, subdf), ax in zip(bigdf.groupby("class"), axs[:2]):
    corr_matrix = subdf.drop(["class"], axis=1).corr(method="pearson")

    im = ax.imshow(corr_matrix, cmap="RdBu", clim=(-1, 1))
    ax.set_title(f"{cl} class")
    ax.grid()
    ax.set_xticks([])
    ax.set_yticks([])

# Create a colorbar
cbar = plt.colorbar(im, cax=axs[2], orientation="horizontal")
cbar.set_label("Correlation")

# axs[4].axis('off')  # Turn off the axis for the colorbar subplot

# plt.tight_layout()
plt.savefig(
    os.path.join("results", results_subfolder, "corr_matrix_after.pdf"),
    bbox_inches="tight",
)
plt.show()

# %%
import json

with open(os.path.join("results", results_subfolder, "drop_features.txt"), "w") as f:
    json.dump(drop_features, f, indent=2)
